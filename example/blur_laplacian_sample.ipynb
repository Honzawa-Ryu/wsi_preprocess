# %%
import sys, os
sys.path.append("..")
import numpy as np
import matplotlib.pyplot as plt
from openslide import OpenSlide
from blur_laplacian import get_blur

# %%
file = "/workspace/01-toxicological-data-extractor/data/collected_data/9073.svs"
patch_size = 256
kernel = 'near4'

# %%
# 数分かかります。
wsi = OpenSlide(file)
blur = get_blur(wsi, patch_size, kernel, show_tqdm=True)

fig, ax = plt.subplots(1,1,figsize=(6,6))
img = ax.imshow(blur)
fig.colorbar(img, ax=ax)
# Out:
#   0%|          | 0/233 [00:00<?, ?it/s]
# 100%|██████████| 233/233 [00:47<00:00,  4.92it/s]
